# %%
import h5py
import numpy as np
import os

root_path = '/workspace/data/GOPRO/train'
h5_folder = os.listdir(root_path)
h5_folder.sort()
total_rmse = 0
threshold = 0.1

for h5 in h5_folder:
    h5_path = os.path.join(root_path, h5)
    with h5py.File(h5_path, 'a') as f:
        print(f"\n### Inspecting file: {h5} ###")
        # print("Existing keys:", list(f.keys()))
        
        # 'images' 그룹에서 blur 이미지 불러오기
        imgs = f['images']
        gen_event = f['gen_event']
        gt_event = f['voxels']

        for event in gen_event:
            event_data = gen_event[f'{event}'][:]
            gt_event_data = gt_event[f'voxel{event[5:]}'][:]
  
            event_data[np.abs(event_data) <= threshold] = 0
            gt_event_data[np.abs(gt_event_data) <= threshold] = 0

            # gen_max_val = np.max(np.abs(event_data))
            gt_max_val = np.max(np.abs(gt_event_data))

            # event_data = event_data / gen_max_val
            gt_event_data = gt_event_data / gt_max_val

            event_data = (event_data + 1) / 2.0
            gt_event_data = (gt_event_data + 1) / 2.0
            rmse = np.sqrt(np.mean((event_data - gt_event_data) ** 2))

            
            total_rmse += rmse
   

print(total_rmse / 2059)
# Out:
# ### Inspecting file: GOPR0372_07_00.h5 ###
#
# ### Inspecting file: GOPR0372_07_01.h5 ###
#
# ### Inspecting file: GOPR0374_11_00.h5 ###
#
# ### Inspecting file: GOPR0374_11_01.h5 ###
#
# ### Inspecting file: GOPR0374_11_02.h5 ###
#
# ### Inspecting file: GOPR0374_11_03.h5 ###
#
# ### Inspecting file: GOPR0378_13_00.h5 ###
#
# ### Inspecting file: GOPR0379_11_00.h5 ###
#
# ### Inspecting file: GOPR0380_11_00.h5 ###
#
# ### Inspecting file: GOPR0384_11_01.h5 ###
#
# ### Inspecting file: GOPR0384_11_02.h5 ###
#
# ### Inspecting file: GOPR0384_11_03.h5 ###
#
# ### Inspecting file: GOPR0384_11_04.h5 ###
#
# ### Inspecting file: GOPR0385_11_00.h5 ###
#
# ### Inspecting file: GOPR0386_11_00.h5 ###
#
# ### Inspecting file: GOPR0477_11_00.h5 ###
#
# ### Inspecting file: GOPR0857_11_00.h5 ###
#
# ### Inspecting file: GOPR0868_11_01.h5 ###
#
# ### Inspecting file: GOPR0868_11_02.h5 ###
#
# ### Inspecting file: GOPR0871_11_01.h5 ###
#
# ### Inspecting file: GOPR0881_11_00.h5 ###
#
# ### Inspecting file: GOPR0884_11_00.h5 ###
# 0.021786862824631437

# %%
import h5py
import numpy as np
import os

root_path = '/workspace/data/GOPRO/test'
h5_folder = os.listdir(root_path)
h5_folder.sort()
total_rmse = 0
threshold = 0.05

for h5 in h5_folder:
    h5_path = os.path.join(root_path, h5)
    with h5py.File(h5_path, 'a') as f:
        print(f"\n### Inspecting file: {h5} ###")
        # print("Existing keys:", list(f.keys()))
        
        # 'images' 그룹에서 blur 이미지 불러오기
        imgs = f['images']
        gen_event = f['gen_event_dit']
        gt_event = f['voxels']

        for event in gen_event:
            event_data = gen_event[f'{event}'][:]
            gt_event_data = gt_event[f'voxel{event[5:]}'][:]

            event_data[np.abs(event_data) <= threshold] = 0
            gt_event_data[np.abs(gt_event_data) <= threshold] = 0

            # gen_max_val = np.max(np.abs(event_data))
            gt_max_val = np.max(np.abs(gt_event_data))

            # event_data = event_data / gen_max_val
            gt_event_data = gt_event_data / gt_max_val

            event_data = (event_data + 1) / 2.0
            gt_event_data = (gt_event_data + 1) / 2.0
            rmse = np.sqrt(np.mean((event_data - gt_event_data) ** 2))

            
            total_rmse += rmse
   

print(total_rmse / 1089)
# Out:
# ### Inspecting file: GOPR0384_11_00.h5 ###
#
# ### Inspecting file: GOPR0384_11_05.h5 ###
#
# ### Inspecting file: GOPR0385_11_01.h5 ###
#
# ### Inspecting file: GOPR0396_11_00.h5 ###
#
# ### Inspecting file: GOPR0410_11_00.h5 ###
#
# ### Inspecting file: GOPR0854_11_00.h5 ###
#
# ### Inspecting file: GOPR0862_11_00.h5 ###
#
# ### Inspecting file: GOPR0868_11_00.h5 ###
#
# ### Inspecting file: GOPR0869_11_00.h5 ###
#
# ### Inspecting file: GOPR0871_11_00.h5 ###
#
# ### Inspecting file: GOPR0881_11_01.h5 ###
# 0.022820883309956096

# %%
import h5py
import numpy as np
import os

root_path = '/workspace/data/GOPRO/test'
h5_folder = os.listdir(root_path)
h5_folder.sort()
total_rmse = 0
threshold = 0.1

for h5 in h5_folder:
    h5_path = os.path.join(root_path, h5)
    with h5py.File(h5_path, 'a') as f:
        print(f"\n### Inspecting file: {h5} ###")
        # print("Existing keys:", list(f.keys()))
        
        # 'images' 그룹에서 blur 이미지 불러오기
        imgs = f['images']
        gen_event = f['gen_event_dit']
        gt_event = f['voxels']

        for event in gen_event:
            event_data = gen_event[f'{event}'][:]
            gt_event_data = gt_event[f'voxel{event[5:]}'][:]

            event_data[np.abs(event_data) <= threshold] = 0
            gt_event_data[np.abs(gt_event_data) <= threshold] = 0

            # gen_max_val = np.max(np.abs(event_data))
            gt_max_val = np.max(np.abs(gt_event_data))

            # event_data = event_data / gen_max_val
            gt_event_data = gt_event_data / gt_max_val

            event_data = (event_data + 1) / 2.0
            gt_event_data = (gt_event_data + 1) / 2.0
            rmse = np.sqrt(np.mean((event_data - gt_event_data) ** 2))

            
            total_rmse += rmse
   

print(total_rmse / 1089)
# Out:
# ### Inspecting file: GOPR0384_11_00.h5 ###
#
# ### Inspecting file: GOPR0384_11_05.h5 ###
#
# ### Inspecting file: GOPR0385_11_01.h5 ###
#
# ### Inspecting file: GOPR0396_11_00.h5 ###
#
# ### Inspecting file: GOPR0410_11_00.h5 ###
#
# ### Inspecting file: GOPR0854_11_00.h5 ###
#
# ### Inspecting file: GOPR0862_11_00.h5 ###
#
# ### Inspecting file: GOPR0868_11_00.h5 ###
#
# ### Inspecting file: GOPR0869_11_00.h5 ###
#
# ### Inspecting file: GOPR0871_11_00.h5 ###
#
# ### Inspecting file: GOPR0881_11_01.h5 ###
# 0.022356438363283954

# %%
import h5py
import numpy as np
import os

root_path = '/workspace/data/GOPRO/test'
h5_folder = os.listdir(root_path)
h5_folder.sort()
total_rmse = 0
threshold = 0.05

gen_event_mother_path = '/workspace/FFTformer/results/Gopro_test/visualization'

for h5 in h5_folder:
    h5_path = os.path.join(root_path, h5)
    with h5py.File(h5_path, 'a') as f:
        print(f"\n### Inspecting file: {h5} ###")
        # print("Existing keys:", list(f.keys()))
        scene = h5_path.split('/')[-1][:-3]
        
        
        gt_event = f['voxels']

        for event in gt_event:  # voxel000000000
            event_data = gt_event[f'{event}'][:]
            img_tag = f'image{event[8:]}'
            
            gen_event_path = os.path.join(gen_event_mother_path, scene, img_tag, 'out.npy')
            gen_event_data = np.load(gen_event_path)

            gen_event_data[np.abs(gen_event_data) <= threshold] = 0
            event_data[np.abs(event_data) <= threshold] = 0
            
            max_val = np.max(np.abs(event_data))
            event_data = event_data / max_val



            gen_event_data = (gen_event_data + 1) / 2.0
            gt_event_data = (event_data + 1) / 2.0

            rmse = np.sqrt(np.mean((gen_event_data - gt_event_data) ** 2))

            
            total_rmse += rmse
   

print(total_rmse / 1089)
# Out:
# ### Inspecting file: GOPR0384_11_00.h5 ###
#
# ### Inspecting file: GOPR0384_11_05.h5 ###
#
# ### Inspecting file: GOPR0385_11_01.h5 ###
#
# ### Inspecting file: GOPR0396_11_00.h5 ###
#
# ### Inspecting file: GOPR0410_11_00.h5 ###
#
# ### Inspecting file: GOPR0854_11_00.h5 ###
#
# ### Inspecting file: GOPR0862_11_00.h5 ###
#
# ### Inspecting file: GOPR0868_11_00.h5 ###
#
# ### Inspecting file: GOPR0869_11_00.h5 ###
#
# ### Inspecting file: GOPR0871_11_00.h5 ###
#
# ### Inspecting file: GOPR0881_11_01.h5 ###
# 0.019925449374478217

# %%
import h5py
import numpy as np
import os

root_path = '/workspace/data/GOPRO/test'
h5_folder = os.listdir(root_path)
h5_folder.sort()
total_rmse = 0
threshold = 0.1

gen_event_mother_path = '/workspace/FFTformer/results/Gopro_test/visualization'

for h5 in h5_folder:
    h5_path = os.path.join(root_path, h5)
    with h5py.File(h5_path, 'a') as f:
        print(f"\n### Inspecting file: {h5} ###")
        # print("Existing keys:", list(f.keys()))
        scene = h5_path.split('/')[-1][:-3]
        
        
        gt_event = f['voxels']

        for event in gt_event:  # voxel000000000
            event_data = gt_event[f'{event}'][:]
            img_tag = f'image{event[8:]}'
            
            gen_event_path = os.path.join(gen_event_mother_path, scene, img_tag, 'out.npy')
            gen_event_data = np.load(gen_event_path)

            gen_event_data[np.abs(gen_event_data) <= threshold] = 0
            event_data[np.abs(event_data) <= threshold] = 0
            
            max_val = np.max(np.abs(event_data))
            event_data = event_data / max_val



            gen_event_data = (gen_event_data + 1) / 2.0
            gt_event_data = (event_data + 1) / 2.0

            rmse = np.sqrt(np.mean((gen_event_data - gt_event_data) ** 2))

            
            total_rmse += rmse
   

print(total_rmse / 1089)
# Out:
# ### Inspecting file: GOPR0384_11_00.h5 ###
#
# ### Inspecting file: GOPR0384_11_05.h5 ###
#
# ### Inspecting file: GOPR0385_11_01.h5 ###
#
# ### Inspecting file: GOPR0396_11_00.h5 ###
#
# ### Inspecting file: GOPR0410_11_00.h5 ###
#
# ### Inspecting file: GOPR0854_11_00.h5 ###
#
# ### Inspecting file: GOPR0862_11_00.h5 ###
#
# ### Inspecting file: GOPR0868_11_00.h5 ###
#
# ### Inspecting file: GOPR0869_11_00.h5 ###
#
# ### Inspecting file: GOPR0871_11_00.h5 ###
#
# ### Inspecting file: GOPR0881_11_01.h5 ###
# 0.019091856996019955

# %%
import h5py
import numpy as np
import os

root_path = '/workspace/data/GOPRO/train'
h5_folder = os.listdir(root_path)
h5_folder.sort()
total_rmse = 0
threshold = 0.1

gen_event_mother_path = '/workspace/FFTformer/results/Gopro_train/visualization'

for h5 in h5_folder:
    h5_path = os.path.join(root_path, h5)
    with h5py.File(h5_path, 'a') as f:
        print(f"\n### Inspecting file: {h5} ###")
        # print("Existing keys:", list(f.keys()))
        scene = h5_path.split('/')[-1][:-3]
        
        
        gt_event = f['voxels']

        for event in gt_event:  # voxel000000000
            event_data = gt_event[f'{event}'][:]
            img_tag = f'image{event[8:]}'
            
            gen_event_path = os.path.join(gen_event_mother_path, scene, img_tag, 'out.npy')
            gen_event_data = np.load(gen_event_path)

            gen_event_data[np.abs(gen_event_data) <= threshold] = 0
            event_data[np.abs(event_data) <= threshold] = 0
            
            max_val = np.max(np.abs(event_data))
            event_data = event_data / max_val



            gen_event_data = (gen_event_data + 1) / 2.0
            gt_event_data = (event_data + 1) / 2.0

            rmse = np.sqrt(np.mean((gen_event_data - gt_event_data) ** 2))

            
            total_rmse += rmse
   

print(total_rmse / 2059)
# Out:
# ### Inspecting file: GOPR0372_07_00.h5 ###
#
# ### Inspecting file: GOPR0372_07_01.h5 ###
#
# ### Inspecting file: GOPR0374_11_00.h5 ###
#
# ### Inspecting file: GOPR0374_11_01.h5 ###
#
# ### Inspecting file: GOPR0374_11_02.h5 ###
#
# ### Inspecting file: GOPR0374_11_03.h5 ###
#
# ### Inspecting file: GOPR0378_13_00.h5 ###
#
# ### Inspecting file: GOPR0379_11_00.h5 ###
#
# ### Inspecting file: GOPR0380_11_00.h5 ###
#
# ### Inspecting file: GOPR0384_11_01.h5 ###
#
# ### Inspecting file: GOPR0384_11_02.h5 ###
#
# ### Inspecting file: GOPR0384_11_03.h5 ###
#
# ### Inspecting file: GOPR0384_11_04.h5 ###
#
# ### Inspecting file: GOPR0385_11_00.h5 ###
#
# ### Inspecting file: GOPR0386_11_00.h5 ###
#
# ### Inspecting file: GOPR0477_11_00.h5 ###
#
# ### Inspecting file: GOPR0857_11_00.h5 ###
#
# ### Inspecting file: GOPR0868_11_01.h5 ###
#
# ### Inspecting file: GOPR0868_11_02.h5 ###
#
# ### Inspecting file: GOPR0871_11_01.h5 ###
#
# ### Inspecting file: GOPR0881_11_00.h5 ###
#
# ### Inspecting file: GOPR0884_11_00.h5 ###
# 0.017764168024794056
